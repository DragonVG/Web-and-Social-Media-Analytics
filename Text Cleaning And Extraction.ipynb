# %% [markdown]
# ## **I. Text cleaning**
# We clean the reviews by removing unnecessary details in the reviews. We then remove the stop words from the data to retain important words in the reviews - Use of stop words list customized for this analysis We also customize the positive and negative word list to get an exhaustive list of sentiment words

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Step 1: Importing libraries and reading the data

# %%
import pandas as pd
import numpy as np

# %%
#reading the merged data --> phone data + metadata
phone_data = pd.read_csv('/content/drive/My Drive/sentiment_analysis/phone_reviews.csv')

# %%
# Reading the phone reviews text into a list

phone_review = phone_data['reviewText']

# %%
phone_data['reviewText'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Step 2: Removing punctuations/special characters

# %%
#Creating a list 'cleaned_review' to store all reviews with punctuations removed

import re

cleaned_review = []
for review in range(0, len(phone_review)):  
    # Remove all the special characters
    processed_review = re.sub(r'[^\w\d\'\s]+', ' ', str(phone_review[review]))
 
    # remove all single characters
    processed_review = re.sub(r'\s+[a-zA-Z]\s+\n', ' ', processed_review)
 
    # Remove single characters from the start
    processed_review = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_review) 
 
    # Substituting multiple spaces with single space
    processed_review= re.sub(r'\s+', ' ', processed_review, flags=re.I)
 
    # Removing prefixed 'b'
    processed_review = re.sub(r'^b\s+', '', processed_review)
 
    # Converting to Lowercase
    processed_review = processed_review.lower()
 
    cleaned_review.append(processed_review)
    
len(cleaned_review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-101b9c7d56d3> in <module>()
#       4
#       5 cleaned_review = []
# ----> 6 for review in range(0, len(phone_review)):
#       7     # Remove all the special characters
#       8     processed_review = re.sub(r'[^\w\d\'\s]+', ' ', str(phone_review[review]))
#
# NameError: name 'phone_review' is not defined

# %% [markdown]
# # Step 3: Removing stopwords

# %%
# Reading stop words from a text file in to a list
stop_words = [line.rstrip('\n') for line in open('/content/drive/My Drive/sentiment_analysis/stop_words_long.txt')]
len(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Removing stop words from all reviews

no_stopwords_review = []  #the list which holds the final cleaned review

for review in cleaned_review:
    word_tokens = review.split() #Tokenization
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    #Appending the list of filtered words
    no_stopwords_review.append(' '.join(filtered_sentence))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f1c33078808d> in <module>()
#       3 no_stopwords_review = []  #the list which holds the final cleaned review
#       4
# ----> 5 for review in cleaned_review:
#       6     word_tokens = review.split() #Tokenization
#       7     filtered_sentence = [w for w in word_tokens if not w in stop_words]
#
# NameError: name 'cleaned_review' is not defined

# %%
# Adding the cleaned reviews to the data frame phone_data

phone_data['cleaned_reviewText'] = no_stopwords_review

# %%
# Printing the data type of the columns
phone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62091 entries, 0 to 62090
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   overall             62091 non-null  float64
#  1   verified            62091 non-null  bool
#  2   reviewerID          62091 non-null  object
#  3   asin                62091 non-null  object
#  4   reviewText          62091 non-null  object
#  5   asin.1              62091 non-null  object
#  6   unixReviewTime      62091 non-null  int64
#  7   category            62091 non-null  object
#  8   also_view           62091 non-null  object
#  9   brand               62025 non-null  object
#  10  price               28382 non-null  object
#  11  review_sentiment    62091 non-null  object
#  12  cleaned_reviewText  62091 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 5.7+ MB

# %%
# Cleaned reviews are of object type which means there are some blank reviews after cleaning. To remove that,
phone_data=phone_data.loc[~(phone_data['cleaned_reviewText']=='')]

# %%
phone_data.shape
# Out:
# (61946, 13)

# %%
# Writing the dataframe phone_data into a csv file
phone_data.to_csv("/content/drive/My Drive/sentiment_analysis/review_sentiment.csv",index = False)

# %% [markdown]
# ## **II. Feature Extraction**

# %% [markdown]
# # Step 1: Importing libraries and reading the data

# %%
# Importing libraries and reading the data
import pandas as pd
phone_data = pd.read_csv("/content/drive/My Drive/sentiment_analysis/review_sentiment.csv")

# %%
phone_data.columns
# Out:
# Index(['overall', 'verified', 'reviewerID', 'asin', 'reviewText', 'asin.1',
#        'unixReviewTime', 'category', 'also_view', 'brand', 'price',
#        'review_sentiment', 'cleaned_reviewText'],
#       dtype='object')

# %%
#Extracting only the required columns
phone_data_col = phone_data[['overall', 'verified', 'unixReviewTime', 'reviewerID',
       'asin', 'reviewText', 'category', 'also_view','brand', 'price', 'cleaned_reviewText','review_sentiment']]

# %% [markdown]
# # Step 2: Converting Unix Review Time to Date-Time format

# %%
#Transforming unixReview time to date time format
from datetime import datetime, timedelta
phone_data_col['Date&Time'] = phone_data_col['unixReviewTime'].apply(lambda d: (datetime.fromtimestamp(d) - timedelta(hours=2)).strftime('%Y-%m-%d'))

# %%
phone_data_col.head()
# Out:
#    overall  verified  ...  review_sentiment   Date&Time
# 0      1.0     False  ...          NEGATIVE  2004-09-20
# 1      4.0     False  ...          POSITIVE  2004-07-23
# 2      3.0     False  ...          NEGATIVE  2004-07-05
# 3      5.0      True  ...          POSITIVE  2004-04-11
# 4      3.0     False  ...          POSITIVE  2004-02-18
#
# [5 rows x 13 columns]

# %% [markdown]
# # Step 3: Finding the "also viewed" phones and their brands for each of the phones

# %%
import ast
import sys

# In the 'also_view' column which contains the asin numbers of also viewed products, only the asins which are present in metadata
# are extracted and stored in another column

# Function that takes intersection of also viewed asins in phone data and the asins in meta data
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 


#Using Brands and Asins to get the also viewed asins which are mobile phones

data_brand_asin = pd.read_csv('/content/drive/My Drive/sentiment_analysis/Brands and Asins.csv')
all_asins = data_brand_asin['asin']


# Empty list that will store the intersected asins 

all_intersected = []

# Looping through the 'also_view' column for each of the entry, calling the intersection function to get the final list of also_viewed asins.
for also_viewed in range(len(phone_data_col['also_view'])):       
    also_viewed_lst = ast.literal_eval(phone_data_col['also_view'][also_viewed])
    intersected = intersection(all_asins, also_viewed_lst)
    all_intersected.append(intersected)
phone_data_col = phone_data_col.copy()
phone_data_col["also_viewed_phones"] = all_intersected

# %%
# Get brands of the also viewed asins

dictionary_of_brands_asins = data_brand_asin.set_index('asin')['brand'].to_dict()
also_viewed_brand = []
for also_viewed_phones in phone_data_col["also_viewed_phones"]:
    also_viewed_brand.append([dictionary_of_brands_asins.get(e,'') for e in also_viewed_phones])
phone_data_col = phone_data_col.copy()
phone_data_col['also_viewed_brand'] = also_viewed_brand

# %%
phone_data_col.head()
# Out:
#    overall  verified  ...  also_viewed_phones also_viewed_brand
# 0      1.0     False  ...                  []                []
# 1      4.0     False  ...                  []                []
# 2      3.0     False  ...                  []                []
# 3      5.0      True  ...                  []                []
# 4      3.0     False  ...                  []                []
#
# [5 rows x 15 columns]

# %%
#save the phone_data_col dataframe having the also viewed brands to a csv 
phone_data_col.to_csv("/content/drive/My Drive/sentiment_analysis/phone_data_final.csv")

# %% [markdown]
# # Step 4: Getting the number of reviews for each brand

# %%
#Getting review count of each brand
dict_brands=phone_data_col['brand'].value_counts().to_dict()
dict_brands
# Out:
# {'0': 5,
#  'A Phone': 7,
#  'ASUS': 17,
#  'AT&T': 189,
#  'AXCELLE': 14,
#  'Acer': 9,
#  'Aeku': 13,
#  'Alcatel': 506,
#  'Amar': 5,
#  'AmericanPumpkins.com': 6,
#  'Apple': 3639,
#  'Asus': 786,
#  'BLU': 9144,
#  'Best Deal USA 2013': 8,
#  'BlackBerry': 3643,
#  'CT-Miami LLC': 134,
#  'CUBOT': 32,
#  'Casio': 77,
#  'Caterpillar': 48,
#  'Cell Phone': 6,
#  'Cell.': 6,
#  'China': 6,
#  'Coolpad': 10,
#  'CovertSafe': 19,
#  'DOOGEE': 54,
#  'Dell': 39,
#  'Diswoe': 5,
#  'Doro': 5,
#  'E-Passion': 5,
#  'ECOOPRO': 23,
#  'F FORITO': 24,
#  'FIGO': 23,
#  'Firefly': 16,
#  'FreedomPop': 18,
#  'Fsmart': 18,
#  'GB': 10,
#  'Generic': 33,
#  'GlocalMe': 10,
#  'Google': 60,
#  'GreatCall': 99,
#  'HAWEEL': 12,
#  'HP': 25,
#  'HTC': 2425,
#  'Hipipooo': 5,
#  'Hot Global': 6,
#  'Huawei': 1393,
#  'IRULU': 17,
#  'JIAKE': 35,
#  'JUST5': 11,
#  'Jabra': 31,
#  'Jethro': 13,
#  'Jitterbug': 27,
#  'KATA': 5,
#  'KINGWELL': 19,
#  'Kata': 15,
#  'Kocaso': 9,
#  'Kyocera': 267,
#  'LAUDE': 14,
#  'LG': 6513,
#  'LG Electronics': 17,
#  'LGIC': 366,
#  'LSoug': 10,
#  'Leagoo': 6,
#  'Lenovo': 252,
#  'LightInTheBox': 6,
#  'Lightahead': 6,
#  'Lynxx': 7,
#  'MASAI STORE': 18,
#  'MOTCB': 179,
#  'Mango Natural': 13,
#  'Microsoft': 223,
#  'Moonar': 5,
#  'Moto X': 29,
#  'Motorola': 4794,
#  'Moxee': 8,
#  'NEC': 6,
#  'NUU': 19,
#  'Newisland': 15,
#  'Nextbit': 114,
#  'Nokia': 4377,
#  'OUKITEL': 7,
#  'OUKU': 7,
#  'OnePlus': 69,
#  'OneTouch': 10,
#  'Otium': 5,
#  'OtterBox': 12,
#  'PCTVSHOP': 22,
#  'PULUZ': 7,
#  'Padgene': 6,
#  'Palm': 214,
#  'Palm Treo 650': 6,
#  'Pantech': 229,
#  'Peek': 6,
#  'Peirui': 11,
#  'Plum': 22,
#  'Polaroid': 32,
#  'Posh Mobile': 394,
#  'Quality Technology Industrial Co., ltd.': 5,
#  'Que Products': 10,
#  'RCA': 186,
#  'REPHONE09': 6,
#  'Raytine': 190,
#  'Republic Wireless': 5,
#  'Risio': 7,
#  'RugGear': 6,
#  'SHARKK': 131,
#  'SKY Devices': 39,
#  'SVP': 39,
#  'Samsung': 15948,
#  'Samsung Korea': 143,
#  'Sanyo': 57,
#  'Sharp': 72,
#  "Shkembi's": 5,
#  'Sidekick': 31,
#  'Sonim': 5,
#  'Sony': 1545,
#  'Sony Ericsson': 162,
#  'SoonerSoft Electronics': 29,
#  'Star': 98,
#  'Sudroid': 8,
#  'T-Mobile': 105,
#  'TNSO': 35,
#  'TRACFONE WIRELESS, INC.': 208,
#  'TokyoSlurpKINGS': 50,
#  'Toto': 19,
#  'TracFone': 5,
#  'Tracfone': 620,
#  'Tracone': 38,
#  'TrimDish': 21,
#  'UNKNOWN': 10,
#  'Ulefone': 11,
#  'Unknown': 7,
#  'Unlocked Cellphone': 9,
#  'Verizon': 32,
#  'Virgin Mobile Slice': 5,
#  'Visikey': 5,
#  'Yezz': 20,
#  'ZTE': 623,
#  'ZTE USA': 48,
#  'binj': 9,
#  'feiteng': 17,
#  'iGearPro': 12,
#  'iRULU': 25,
#  'inDigi': 6,
#  'redmi': 6,
#  'verykool': 65}

# %%
#club reviews which are less than 1000 reviews

dict_brands_filtered = {}
sum = 0
for key, value in dict_brands.items():
    if value > 1000:
        dict_brands_filtered[key] = value
    else:
        sum  = sum + value
dict_brands_filtered['Others'] = sum  
dict_brands_filtered
# Out:
# {'Apple': 3639,
#  'BLU': 9144,
#  'BlackBerry': 3643,
#  'HTC': 2425,
#  'Huawei': 1393,
#  'LG': 6513,
#  'Motorola': 4794,
#  'Nokia': 4377,
#  'Others': 8459,
#  'Samsung': 15948,
#  'Sony': 1545}

# %%
#getting data for only those top brands which have more than 1000 reviews -- comes to 10 brands

top_10_brands = ['Samsung',
 'Motorola',
 'LG',
 'BlackBerry',
 'Nokia',
 'Apple',
 'HTC',
 'BLU',
 'Huawei',
 'Sony']
phone_data_top_10 = phone_data_col[phone_data_col.brand.isin(top_10_brands)]
phone_data_top_10 = phone_data_top_10.reset_index()

# %%
phone_data_top_10.head()
# Out:
#    index  overall  verified  ...   Date&Time also_viewed_phones also_viewed_brand
# 0      0      1.0     False  ...  2004-09-20                 []                []
# 1      1      4.0     False  ...  2004-07-23                 []                []
# 2      2      3.0     False  ...  2004-07-05                 []                []
# 3      3      5.0      True  ...  2004-04-11                 []                []
# 4      4      3.0     False  ...  2004-02-18                 []                []
#
# [5 rows x 16 columns]

# %%
#getting count of also viewed for each brand for top 10 brands
#for every purchased brand get the count of also viewed brand
brand =  phone_data_top_10['brand']

also_viewed_brands = phone_data_top_10['also_viewed_brand']
dict_also_viewed_brands = {}

for i in range(len(brand)):
    if brand[i] not in dict_also_viewed_brands:
        dict_also_viewed_brands[brand[i]] = {}
    for j in range(len(also_viewed_brands[i])):
        if also_viewed_brands[i][j] not in dict_also_viewed_brands[brand[i]]:
            dict_also_viewed_brands[brand[i]][also_viewed_brands[i][j]] = 1
        else:
            dict_also_viewed_brands[brand[i]][also_viewed_brands[i][j]] = int(dict_also_viewed_brands[brand[i]][also_viewed_brands[i][j]]) + 1

# %%
dict_also_viewed_brands
# Out:
# {'Apple': {'Apple': 14018,
#   'LG': 28,
#   'Straight Talk': 12,
#   'Sudroid': 241,
#   'ZTE': 12},
#  'BLU': {'Alcatel': 282,
#   'Alcatel One Touch': 956,
#   'Apple': 61,
#   'BLU': 8016,
#   'BlackBerry': 270,
#   'Casio': 48,
#   'Caterpillar': 164,
#   'GreatCall': 216,
#   'HTC': 132,
#   'Huawei': 10,
#   'Kocaso': 38,
#   'Kyocera': 151,
#   'LG': 963,
#   'Microsoft': 331,
#   'Motorola': 978,
#   'Nokia': 1022,
#   'OnePlus': 18,
#   'Pantech': 264,
#   'RCA': 300,
#   'Samsung': 1129,
#   'Sony': 650,
#   'Tracfone': 7,
#   'ZTE': 2146,
#   'ZTE USA': 93,
#   nan: 48},
#  'BlackBerry': {'Alcatel': 21,
#   'Alcatel One Touch': 6,
#   'BLU': 691,
#   'BlackBerry': 45225,
#   'Blackberry': 8,
#   'Casio': 163,
#   'Caterpillar': 63,
#   'Fsmart': 96,
#   'GreatCall': 108,
#   'HTC': 86,
#   'Kyocera': 485,
#   'LG': 4551,
#   'Motorola': 697,
#   'Nokia': 198,
#   'Palm': 6,
#   'Pantech': 1158,
#   'Porsche Design': 401,
#   'RCA': 9,
#   'RugGear': 46,
#   'Samsung': 1141,
#   'Sanyo': 16,
#   'Sony': 47,
#   'Storm': 171,
#   'Unknown': 147,
#   'Verizon': 15,
#   'ZTE': 3428,
#   'ZTE USA': 109,
#   nan: 28},
#  'HTC': {'AT&T': 72,
#   'Alcatel': 98,
#   'Alcatel One Touch': 52,
#   'Apple': 17,
#   'Asus': 72,
#   'BLU': 189,
#   'BlackBerry': 709,
#   'Cell Phone': 14,
#   'GreatCall': 65,
#   'HTC': 12874,
#   'Kyocera': 641,
#   'LG': 3453,
#   'Lynxx': 5,
#   'Microsoft': 98,
#   'Motorola': 1592,
#   'NEC': 11,
#   'Nokia': 332,
#   'OnePlus': 18,
#   'Pantech': 227,
#   'RCA': 175,
#   'RugGear': 84,
#   'Samsung': 2858,
#   'Sanyo': 19,
#   'Sharp': 47,
#   'Sony': 193,
#   'ZTE': 751,
#   nan: 9},
#  'Huawei': {'Alcatel': 12,
#   'Alcatel One Touch': 11,
#   'BLU': 10,
#   'GreatCall': 5,
#   'HTC': 6,
#   'Huawei': 2170,
#   'Kyocera': 17,
#   'LG': 586,
#   'LGIC': 6,
#   'Motorola': 906,
#   'Nexus': 26,
#   'Nokia': 20,
#   'OnePlus': 27,
#   'Samsung': 53,
#   'Sanyo': 5,
#   'Sony': 91,
#   'Tracfone': 18,
#   'ZTE': 77},
#  'LG': {'AT&T': 20,
#   'Alcatel': 269,
#   'Alcatel One Touch': 60,
#   'Asus': 366,
#   'BLU': 683,
#   'BlackBerry': 1050,
#   'Boost': 100,
#   'Casio': 318,
#   'Caterpillar': 95,
#   'Cell.': 5,
#   'Fsmart': 11,
#   'Google': 223,
#   'GreatCall': 300,
#   'HTC': 2109,
#   'Huawei': 81,
#   'Kyocera': 2215,
#   'LG': 34557,
#   'LGIC': 861,
#   'MOTCB': 372,
#   'Microsoft': 92,
#   'Motorola': 3017,
#   'NET10': 7,
#   'Net10': 10,
#   'Nokia': 347,
#   'OnePlus': 28,
#   'Palm': 80,
#   'Pantech': 740,
#   'RCA': 347,
#   'Risio': 5,
#   'RugGear': 201,
#   'Samsung': 9109,
#   'Sanyo': 599,
#   'Snapfon': 27,
#   'Sony': 586,
#   'SoonerSoft Electronics': 44,
#   'TRACFONE WIRELESS, INC.': 780,
#   'TracFone': 54,
#   'Tracfone': 2928,
#   'Tracfone Wireless': 46,
#   'Tracone': 401,
#   'Unknown': 108,
#   'Verizon': 6,
#   'ZTE': 2043,
#   'ZTE USA': 167,
#   nan: 163},
#  'Motorola': {'AMGOO Telecom': 20,
#   'AT&T': 19,
#   'Alcatel': 24,
#   'Alcatel One Touch': 130,
#   'Apple': 136,
#   'Asus': 9,
#   'BLU': 301,
#   'BlackBerry': 1200,
#   'Boost': 7,
#   'Boost Mobile': 7,
#   'Casio': 429,
#   'Caterpillar': 20,
#   'Droid Turbo': 111,
#   'Fsmart': 71,
#   'GreatCall': 763,
#   'HTC': 1546,
#   'Kyocera': 1879,
#   'LG': 4906,
#   'LGIC': 15,
#   'MOTCB': 101,
#   'Moto X': 22,
#   'Motorola': 23248,
#   'NEC': 7,
#   'Nokia': 672,
#   'Pantech': 446,
#   'RCA': 97,
#   'RugGear': 7,
#   'Samsung': 4628,
#   'Sanyo': 14,
#   'Sony': 519,
#   'TRACFONE WIRELESS, INC.': 53,
#   'TracFone': 22,
#   'Tracfone': 253,
#   'Tracone': 45,
#   'Unknown': 21,
#   'Verizon': 7,
#   'ZTE': 1455,
#   'ZTE USA': 82,
#   nan: 671},
#  'Nokia': {'AT&T': 16,
#   'Alcatel': 44,
#   'Alcatel One Touch': 100,
#   'Apple': 46,
#   'Asus': 12,
#   'BLU': 1302,
#   'BlackBerry': 3791,
#   'Casio': 24,
#   'Caterpillar': 143,
#   'Fsmart': 90,
#   'GreatCall': 151,
#   'HTC': 307,
#   'Kyocera': 453,
#   'LG': 2537,
#   'LGIC': 13,
#   'MOTCB': 46,
#   'Microsoft': 3112,
#   'Motorola': 506,
#   'Nokia': 23121,
#   'OnePlus': 23,
#   'Pantech': 653,
#   'Porsche Design': 15,
#   'RCA': 401,
#   'Samsung': 1771,
#   'Sanyo': 138,
#   'Sony': 92,
#   'Sudroid': 6,
#   'T-Mobile': 11,
#   'Tracfone Wireless': 55,
#   'ZTE': 1648,
#   'ZTE USA': 157,
#   nan: 118},
#  'Samsung': {'AT&T': 173,
#   'Alcatel': 451,
#   'Alcatel One Touch': 468,
#   'Apple': 120,
#   'Asus': 877,
#   'BLU': 660,
#   'BlackBerry': 1880,
#   'Boost': 203,
#   'Boost Mobile': 20,
#   'CAT PHONES': 11,
#   'Casio': 368,
#   'Caterpillar': 51,
#   'Fsmart': 26,
#   'Galaxy S5': 1527,
#   'Google': 21,
#   'GreatCall': 460,
#   'HTC': 2061,
#   'Huawei': 163,
#   'Jitterbug': 27,
#   'Kyocera': 2614,
#   'LG': 14077,
#   'LGIC': 171,
#   'MOTCB': 474,
#   'Microsoft': 299,
#   'Motorola': 5932,
#   'NET10': 9,
#   'Nokia': 1112,
#   'Palm': 15,
#   'Pantech': 1414,
#   'RCA': 339,
#   'RugGear': 157,
#   'Samsung': 132136,
#   'Samsung Group': 1232,
#   'Samsung Korea': 746,
#   'Samsung/Straight Talk': 6,
#   'Sanyo': 592,
#   'Sony': 902,
#   'Straight Talk': 8,
#   'Sudroid': 24,
#   'T-Mobile': 85,
#   'TNSO': 289,
#   'TRACFONE WIRELESS, INC.': 71,
#   'TracFone': 29,
#   'Tracfone': 463,
#   'Tracfone Wireless': 28,
#   'Tracone': 43,
#   'Unknown': 39,
#   'Virgin Mobile': 9,
#   'ZTE': 4107,
#   'ZTE USA': 269,
#   'inDigi': 83,
#   nan: 308},
#  'Sony': {'Alcatel One Touch': 26,
#   'BLU': 10,
#   'BlackBerry': 183,
#   'CAT PHONES': 78,
#   'HTC': 74,
#   'Huawei': 34,
#   'Kyocera': 10,
#   'LG': 240,
#   'Motorola': 235,
#   'Nokia': 22,
#   'Pantech': 10,
#   'RugGear': 7,
#   'SKY Devices': 18,
#   'Samsung': 304,
#   'Sony': 6486,
#   'Sony Ericsson': 83,
#   'TNSO': 5,
#   'ZTE': 36,
#   nan: 11}}

# %%
df_viewed_brands = pd.DataFrame(dict_also_viewed_brands).T

# df_viewed_brands.to_excel("viewed_brands.xlsx", index = True)

# %%
df_viewed_brands
# Out:
#              Samsung  BlackBerry  Pantech  ...  Nexus  Sony Ericsson  SKY Devices
# Samsung     132136.0      1880.0   1414.0  ...    NaN            NaN          NaN
# Motorola      4628.0      1200.0    446.0  ...    NaN            NaN          NaN
# LG            9109.0      1050.0    740.0  ...    NaN            NaN          NaN
# BlackBerry    1141.0     45225.0   1158.0  ...    NaN            NaN          NaN
# Nokia         1771.0      3791.0    653.0  ...    NaN            NaN          NaN
# Apple            NaN         NaN      NaN  ...    NaN            NaN          NaN
# HTC           2858.0       709.0    227.0  ...    NaN            NaN          NaN
# BLU           1129.0       270.0    264.0  ...    NaN            NaN          NaN
# Huawei          53.0         NaN      NaN  ...   26.0            NaN          NaN
# Sony           304.0       183.0     10.0  ...    NaN           83.0         18.0
#
# [10 rows x 73 columns]

# %%
#to get the max viewed for each top brand apart from itself
max_viewed = {}
for brand, sub_brand in dict_also_viewed_brands.items():
    also_viewed_brand = ''
    count = 0
    for top_brand, value in sub_brand.items():
        if value > count and brand != top_brand:
            count = value
            also_viewed_brand = top_brand
    max_viewed[brand]  = str(also_viewed_brand) + ' ' + str(count)
max_viewed_df = pd.DataFrame(max_viewed, index = ['top_viewed']).T
max_viewed_df.to_excel("/content/drive/My Drive/sentiment_analysis/Max Viewed.xlsx", index = True)

# %%
max_viewed_df
# Out:
#                  top_viewed
# Samsung            LG 14077
# Motorola            LG 4906
# LG             Samsung 9109
# BlackBerry          LG 4551
# Nokia       BlackBerry 3791
# Apple           Sudroid 241
# HTC                 LG 3453
# BLU                ZTE 2146
# Huawei         Motorola 906
# Sony            Samsung 304

# %% [markdown]
# # Step 5: Extracting the features from positive and negative reviews

# %%
def computeReviewTFDict(review):
    """ Returns a tf dictionary for each review whose keys are all
    the unique words in the review and whose values are their
    corresponding tf.
    """
    # Counts the number of times the word appears in review
    reviewTFDict = {}
    for word in review:
        if word in reviewTFDict:
            reviewTFDict[word] += 1
        else:
            reviewTFDict[word] = 1
    # Computes tf for each word -- (normalize it by dividing it with the length of review)
    for word in reviewTFDict:
        reviewTFDict[word] = reviewTFDict[word] / len(review)
    return reviewTFDict

# %%
#Reading positive words
pos_words = [line.rstrip('\n') for line in open('/content/drive/My Drive/sentiment_analysis/pos_words.txt')]
print(len(pos_words))

#Reading negative words
neg_words = [line.rstrip('\n') for line in open('/content/drive/My Drive/sentiment_analysis/neg_words.txt')]
print(len(neg_words))
# Out:
# 2006
# 4804

# %%
#for getting features removing even the positive and negative words
review_features = []

for review in phone_data_col['cleaned_reviewText']:
    if not isinstance(review, float):
        word_tokens = review.split(' ') 
        filtered_sentence = [w for w in word_tokens if not w in pos_words and not w in neg_words] 
        review_features.append(' '.join(filtered_sentence))

# %%
tfDict = []
for review in review_features:
    word_list = review.split()
    tfDict.append(computeReviewTFDict(word_list))

# %%
def computeCountDict():
    """ Returns a dictionary whose keys are all the unique words in
    the dataset and whose values count the number of reviews in which
    the word appears.
    """
    countDict = {}
    # Run through each review's tf dictionary and increment countDict's (word, doc) pair
    for review in tfDict:
        for word in review:
            if word in countDict:
                countDict[word] += 1
            else:
                countDict[word] = 1
    return countDict

# Stores the review count dictionary
countDict = computeCountDict()
countDict
# Out:
# {'phone': 32164,
#  'heavy': 1168,
#  'user': 2075,
#  'interface': 942,
#  'techies': 18,
#  'drops': 378,
#  'calls': 2727,
#  'manhattan': 6,
#  'moto': 947,
#  'v600': 8,
#  'takes': 2105,
#  'pictures': 2302,
#  'reception': 960,
#  'mobile': 3216,
#  'stay': 590,
#  'samsung': 4378,
#  'v205': 2,
#  'decided': 1064,
#  'try': 1608,
#  'e715': 3,
#  'fyi': 65,
#  'people': 2588,
#  'battery': 9030,
#  'batteries': 455,
#  'completely': 943,
#  'charge': 2534,
#  'building': 92,
#  'life': 5226,
#  'doing': 986,
#  'times': 2132,
#  'immensely': 12,
#  "i've": 3905,
#  'customer': 1114,
#  '1': 3886,
#  'service': 2821,
#  '2': 5678,
#  'rate': 450,
#  'plans': 333,
#  '3': 4574,
#  'additional': 431,
#  'features': 3634,
#  'little': 3837,
#  'gadget': 81,
#  'caller': 115,
#  'id': 292,
#  'pics': 544,
#  'able': 2463,
#  'external': 487,
#  'display': 2106,
#  'flip': 695,
#  "you'll": 880,
#  "person's": 24,
#  'camera': 7070,
#  'flash': 1196,
#  'zoom': 304,
#  'gray': 81,
#  'black': 996,
#  'white': 716,
#  'sepia': 9,
#  'sketch': 9,
#  'multi': 310,
#  'shot': 279,
#  'lots': 737,
#  'frames': 40,
#  'download': 1268,
#  'games': 1533,
#  'whereas': 104,
#  'furthermore': 55,
#  'actually': 2062,
#  'java': 49,
#  '4': 4482,
#  'serve': 79,
#  'flashlight': 206,
#  'sometimes': 1340,
#  "you're": 1603,
#  'walking': 95,
#  'light': 2227,
#  '5': 4914,
#  'voice': 1419,
#  'memo': 53,
#  'nuf': 2,
#  'otherwise': 814,
#  'usual': 241,
#  'calculator': 133,
#  'calendar': 425,
#  'list': 610,
#  'mms': 190,
#  'sms': 235,
#  'ringtones': 257,
#  'help': 1087,
#  'sound': 2191,
#  'stuff': 811,
#  'except': 912,
#  'bluetooth': 1501,
#  'blue': 515,
#  'green': 147,
#  'background': 452,
#  'press': 623,
#  'button': 1833,
#  'time': 6516,
#  'lit': 125,
#  'lookin': 5,
#  'bluish': 15,
#  'color': 1040,
#  'saved': 240,
#  'look': 2221,
#  'overall': 2253,
#  'antenna': 240,
#  'buy': 5005,
#  'measure': 42,
#  'v300': 3,
#  'am': 5070,
#  'tmobile': 402,
#  'finally': 1127,
#  'fed': 27,
#  "v300's": 1,
#  'sent': 922,
#  'upgrade': 1693,
#  'brake': 4,
#  'quality': 5314,
#  'call': 2916,
#  'receiver': 92,
#  'tinny': 95,
#  'sounds': 550,
#  "'digital'": 1,
#  'unlike': 510,
#  'realize': 329,
#  'received': 1598,
#  'maybe': 1219,
#  "'technology'": 1,
#  'phones': 7318,
#  'example': 528,
#  'datebook': 6,
#  'set': 1957,
#  'alarms': 80,
#  'remind': 49,
#  'appointments': 56,
#  'speakerphone': 339,
#  'simply': 1026,
#  'commodore': 2,
#  '64': 264,
#  'computer': 818,
#  'world': 752,
#  '3ghz': 25,
#  'processors': 120,
#  'lastly': 115,
#  "'smart'": 7,
#  'words': 295,
#  'feature': 2076,
#  'packed': 193,
#  'practically': 132,
#  'designed': 444,
#  'cell': 2353,
#  'opinion': 639,
#  'art': 103,
#  'accomodate': 4,
#  'practical': 182,
#  'short': 829,
#  'debating': 49,
#  "i'm": 4716,
#  'europe': 179,
#  'networks': 379,
#  'currently': 612,
#  'software': 2222,
#  'huge': 1189,
#  'nokia': 1478,
#  'fan': 551,
#  'audio': 709,
#  'looks': 2273,
#  'reservations': 41,
#  'whatsoever': 164,
#  'real': 1284,
#  'owned': 1298,
#  'days': 2953,
#  'stand': 405,
#  '10': 1946,
#  'minutes': 1576,
#  'day': 3797,
#  'activated': 494,
#  'dialing': 227,
#  'speaker': 1682,
#  'type': 1018,
#  'hands': 1235,
#  'kit': 266,
#  'car': 881,
#  'answer': 449,
#  'talk': 1330,
#  'dial': 326,
#  'menus': 288,
#  'ir': 136,
#  'sync': 427,
#  'transfer': 553,
#  'cable': 800,
#  'purchase': 2176,
#  'backup': 541,
#  'enter': 248,
#  'photos': 1466,
#  'syncing': 111,
#  'outlook': 157,
#  'pda': 101,
#  'else': 1248,
#  '6': 2485,
#  'ring': 377,
#  'tones': 168,
#  'wallpaper': 144,
#  'size': 3232,
#  'weight': 593,
#  'hold': 1351,
#  'rings': 95,
#  'putting': 358,
#  'standard': 778,
#  'holder': 59,
#  'key': 577,
#  'makes': 2079,
#  'grabs': 5,
#  'purchased': 2116,
#  'charger': 1880,
#  'average': 758,
#  '15': 754,
#  'hours': 1804,
#  'regular': 716,
#  'zones': 27,
#  'minute': 407,
#  'month': 1728,
#  'months': 2583,
#  'total': 388,
#  '9': 656,
#  'transferred': 198,
#  'data': 2457,
#  'twice': 529,
#  'lasted': 391,
#  'home': 1863,
#  '24': 380,
#  'hour': 590,
#  'replace': 1204,
#  'discharged': 25,
#  'lasting': 148,
#  '8': 1811,
#  'offer': 561,
#  'web': 1395,
#  'site': 386,
#  'prices': 227,
#  'wireless': 1023,
#  'modem': 55,
#  'incredibility': 1,
#  'national': 25,
#  'calling': 729,
#  'price': 6968,
#  'compared': 1364,
#  've': 20,
#  'seen': 874,
#  'elsewhere': 179,
#  'bought': 5420,
#  'cellular': 432,
#  'got': 5250,
#  'wait': 808,
#  'couldn': 4,
#  'person': 971,
#  'explosion': 7,
#  'market': 1251,
#  'functionalities': 23,
#  'similar': 784,
#  'extra': 1195,
#  'bells': 278,
#  'whistles': 268,
#  'sells': 136,
#  'product': 5048,
#  'attracted': 25,
#  'styling': 24,
#  'previously': 320,
#  's105': 1,
#  'learn': 414,
#  'menu': 588,
#  'functions': 840,
#  '6610': 1,
#  'internal': 1084,
#  'antennas': 27,
#  'added': 755,
#  '640x480': 19,
#  'ok': 2436,
#  'viewed': 41,
#  "phones'": 20,
#  'screens': 737,
#  'view': 493,
#  '40': 448,
#  'chord': 7,
#  'midi': 4,
#  'means': 898,
#  'songs': 184,
#  'tech': 659,
#  'program': 386,
#  'called': 937,
#  'gprs': 23,
#  'downloaded': 583,
#  "samsung's": 267,
#  'european': 139,
#  'website': 485,
#  'allow': 607,
#  'pc': 416,
#  'psm': 1,
#  'play': 1797,
#  'allows': 704,
#  'edit': 363,
#  'files': 535,
#  'convert': 78,
#  'mmf': 2,
#  'ear': 448,
#  'pieces': 79,
#  'purpose': 261,
#  'minor': 534,
#  'inconvinence': 1,
#  "phone's": 697,
#  'irda': 1,
#  'mentioned': 384,
#  'application': 375,
#  'sony': 685,
#  'ericcson': 5,
#  't610': 7,
#  "window's": 9,
#  'default': 484,
#  'match': 201,
#  'infra': 4,
#  'red': 317,
#  'port': 703,
#  "laptop's": 4,
#  'course': 860,
#  'easygprs': 1,
#  'ability': 618,
#  'wish': 1239,
#  'simple': 1306,
#  'images': 481,
#  'directly': 452,
#  'using': 4662,
#  'windows': 1713,
#  'runs': 1069,
#  'run': 1374,
#  'definitely': 1459,
#  'gsm': 743,
#  'moment': 287,
#  'rebates': 12,
#  'cost': 1295,
#  '50': 809,
#  'cancelling': 30,
#  'account': 685,
#  'starting': 306,
#  'treo': 106,
#  '600': 302,
#  'friday': 131,
#  'treocentral': 1,
#  'sprint': 748,
#  'testing': 227,
#  'comparing': 279,
#  'coverage': 460,
#  'verizon': 1806,
#  'nextel': 25,
#  'found': 2115,
#  'signal': 1186,
#  'bar': 463,
#  "nextel's": 1,
#  'pdaphone': 1,
#  'compare': 534,
#  'grafitti': 1,
#  'palm': 281,
#  'i705': 1,
#  'net': 210,
#  'replaces': 66,
#  'pilot': 17,
#  'device': 3223,
#  'lower': 597,
#  'monthly': 332,
#  'bill': 285,
#  'unit': 563,
#  'title': 83,
#  'review': 2126,
#  'sums': 9,
#  'hopefully': 323,
#  '650': 71,
#  'wifi': 2168,
#  'xda': 66,
#  'iii': 97,
#  'mate': 72,
#  'blackberry': 1044,
#  'email': 1326,
#  'consulting': 3,
#  'business': 639,
#  'bulletproof': 5,
#  "what's": 274,
#  'browser': 665,
#  'yes': 1178,
#  'bes': 8,
#  '7510': 1,
#  'reqwireless': 1,
#  'major': 726,
#  'applications': 678,
#  'written': 166,
#  'primarily': 129,
#  'pony': 8,
#  'giving': 484,
#  'tried': 1668,
#  'evaluate': 30,
#  'included': 846,
#  '100': 1841,
#  'signficant': 1,
#  'third': 535,
#  'party': 428,
#  'relatively': 264,
#  'highly': 1144,
#  'customizable': 254,
#  '3rd': 318,
#  'require': 328,
#  'department': 135,
#  'configure': 106,
#  'exchange': 298,
#  'server': 105,
#  'bb': 252,
#  'automatic': 137,
#  'push': 376,
#  'manually': 255,
#  'retrieve': 31,
#  'poll': 6,
#  'interval': 6,
#  'snapper': 5,
#  'seven': 67,
#  'connection': 779,
#  'keyboard': 1729,
#  'users': 841,
#  'report': 152,
#  'units': 86,
#  'prone': 105,
#  'breakage': 10,
#  'surprised': 552,
#  'experience': 1662,
#  'initially': 264,
#  'held': 272,
#  'evaluating': 12,
#  "i'd": 1079,
#  'heard': 468,
#  'weeks': 1171,
#  'usage': 883,
#  'resets': 73,
#  'beyond': 287,
#  'intial': 1,
#  'loading': 204,
#  'programs': 304,
#  'rumored': 33,
#  'model': 1447,
#  'coming': 916,
#  'late': 243,
#  '2004': 8,
#  'office': 426,
#  'treos': 7,
#  'piece': 616,
#  'voicedial': 4,
#  'digital': 240,
#  'metropolitan': 8,
#  'problematical': 2,
#  'travels': 40,
#  'rural': 78,
#  'adjusted': 80,
#  'graffiti': 3,
#  'original': 986,
#  'traded': 40,
#  'mine': 1154,
#  'i500': 2,
#  'add': 1217,
#  'ons': 24,
#  'stock': 807,
#  'tri': 18,
#  'band': 346,
#  'pcs': 141,
#  'speed': 1495,
#  'dials': 34,
#  'fits': 715,
#  'pocket': 1319,
#  'pockets': 154,
#  'mp3s': 66,
#  'due': 1139,
#  'memory': 2563,
#  'vs': 340,
#  'ipod': 273,
#  'ripping': 14,
#  'load': 545,
#  'music': 2192,
#  'player': 768,
#  '16mb': 4,
#  'filled': 103,
#  '32mb': 9,
#  'capacity': 378,
#  'card': 4761,
#  'books': 170,
#  'suggest': 315,
#  'carry': 618,
#  'lot': 3444,
#  '7': 1630,
#  'continually': 65,
#  'charging': 1721,
#  'moderate': 390,
#  'conversation': 153,
#  '1500': 20,
#  'sanyos': 3,
#  'pre': 607,
#  'paid': 1013,
#  'unlocked': 2509,
#  'sonyericcson': 1,
#  '610': 14,
#  'overseas': 226,
#  'joysticks': 6,
#  'birds': 97,
#  'trade': 198,
#  'ms': 137,
#  'smartphone': 2403,
#  'locked': 606,
#  'bring': 360,
#  'helps': 438,
#  'decide': 238,
#  'os': 1814,
#  'meaning': 194,
#  'alot': 310,
#  'vga': 69,
#  'outside': 559,
#  'reading': 776,
#  'speakers': 982,
#  'stop': 506,
#  'mp3': 417,
#  'special': 308,
#  'adaptor': 38,
#  'function': 744,
#  "sprint's": 72,
#  'install': 865,
#  'leave': 489,
#  'link': 502,
#  'screen': 9874,
#  'contact': 583,
#  'search': 540,
#  'hit': 567,
#  'letter': 110,
#  'jump': 141,
#  'start': 1089,
#  'keypad': 283,
#  'touch': 2213,
#  'design': 1388,
#  'ton': 305,
#  'money': 2234,
#  'waiting': 586,
#  'goes': 859,
#  'switch': 855,
#  'happens': 329,
#  'tell': 1172,
#  'continue': 284,
#  'rack': 6,
#  'air': 267,
#  'regardless': 146,
#  'intentional': 11,
#  'wipe': 66,
#  'whatever': 432,
#  'figure': 544,
#  'deal': 1890,
#  'frank': 15,
#  'high': 1832,
#  'expectations': 493,
#  'release': 351,
#  'actual': 361,
#  'front': 1858,
#  'deserves': 74,
#  'stars': 1415,
#  'pocketable': 42,
#  'biggest': 520,
#  'minimalistic': 16,
#  'keys': 613,
#  'handspring': 4,
#  'thumboard': 1,
#  'believe': 894,
#  'round': 87,
#  'surface': 196,
#  'fingers': 394,
#  'typing': 446,
#  'spacing': 108,
#  'close': 973,
#  'extremely': 779,
#  'woes': 2,
#  'num': 4,
#  'lock': 669,
#  'numeric': 37,
#  'shift': 68,
#  'thinking': 490,
#  'straight': 747,
#  'accented': 4,
#  'letters': 163,
#  'english': 296,
#  'punctuations': 1,
#  'plain': 150,
#  'viewing': 375,
#  'angle': 163,
#  'unless': 1028,
#  'seeing': 270,
#  'silk': 20,
#  'tungsten': 5,
#  'clie': 2,
#  'feels': 1489,
#  'pixelated': 30,
#  'plan': 1663,
#  'surfing': 279,
#  'prepared': 125,
#  'internet': 1789,
#  'amazon': 2890,
#  "com's": 2,
#  'page': 440,
#  'barely': 440,
#  'layout': 165,
#  "msn's": 1,
#  'reason': 1495,
#  "apple's": 114,
#  'homepage': 14,
#  'messages': 826,
#  'msnbc': 2,
#  'yahoo': 114,
#  "pcs's": 5,
#  'own': 1549,
#  'implementation': 78,
#  'soon': 895,
#  'probably': 1522,
#  '5g': 51,
#  'network': 1568,
#  'hardware': 1025,
#  'se': 135,
#  'anyway': 680,
#  'throw': 215,
#  'feel': 2086,
#  'charity': 3,
#  'generation': 271,
#  'ten': 150,
#  'sf': 7,
#  'bay': 31,
#  'fewer': 90,
#  'dropped': 1166,
#  'volume': 1474,
#  'nx70': 1,
#  'resolution': 1367,
#  'hi': 121,
#  'res': 90,
#  'surprisingly': 342,
#  'video': 2024,
#  'access': 1069,
#  'value': 1002,
#  'contacts': 747,
#  'motorola': 1235,
#  'started': 1072,
#  'kept': 596,
#  'repeated': 40,
#  'trying': 1171,
#  'technical': 240,
#  'center': 220,
#  'returned': 905,
#  'irreperable': 6,
#  'caused': 184,
#  'counts': 35,
#  'comment': 267,
#  'explanation': 57,
#  'reevaluation': 6,
#  'fixing': 52,
#  'replacing': 210,
#  'warranty': 849,
#  'i710': 1,
#  'friends': 660,
#  'downgraded': 33,
#  'main': 912,
#  'chose': 286,
#  'i730': 6,
#  'strength': 219,
#  'matter': 691,
#  'bars': 280,
#  'including': 760,
#  'antennae': 10,
#  'icon': 299,
#  'friend': 569,
#  'i860': 1,
#  "i710's": 1,
#  "i730's": 1,
#  'significantly': 192,
#  'based': 638,
#  'differences': 145,
#  'somehow': 156,
#  'basically': 587,
#  'identical': 132,
#  'construction': 181,
#  'silver': 140,
#  'leaps': 31,
#  'bounds': 26,
#  'previous': 1007,
#  'interfaces': 46,
#  'text': 2211,
#  'messaging': 469,
#  'profiles': 59,
#  'enable': 134,
#  'quickly': 1352,
#  'meetings': 39,
#  'vibe': 16,
#  'direct': 318,
#  'connect': 749,
#  'personal': 517,
#  'buying': 1360,
#  'body': 355,
#  'glove': 35,
#  'cover': 1162,
#  'clip': 105,
#  'scuba': 1,
#  'tuxedo': 2,
#  'past': 769,
#  'moved': 324,
#  'okay': 681,
#  'i1000': 2,
#  'couple': 1372,
#  'i90': 1,
#  'recently': 523,
#  'professionalism': 6,
#  'begin': 151,
#  'offers': 515,
#  'carrier': 1102,
#  'looked': 697,
#  'carriers': 492,
#  'none': 571,
#  '1st': 227,
#  'treat': 59,
#  'instructions': 307,
#  'documented': 30,
#  'rocket': 19,
#  'science': 12,
#  'navigate': 298,
#  'ness': 27,
#  'aesthetic': 58,
#  'please': 679,
#  'yourself': 468,
#  'pick': 489,
#  'proof': 216,
#  'family': 638,
#  'compliants': 2,
#  'roam': 19,
#  'traveling': 169,
#  'emergencies': 83,
#  'remedied': 34,
#  'tracfone': 664,
#  'com': 515,
#  'plus': 1752,
#  'models': 481,
#  'night': 719,
#  'middle': 358,
#  'workday': 22,
#  '2nd': 359,
#  'especially': 1362,
#  'luckily': 154,
#  'recharge': 179,
#  'quick': 1332,
#  'delivery': 455,
#  'driver': 139,
#  'michigan': 6,
#  'types': 120,
#  'weather': 282,
#  'downpour': 1,
#  'specifically': 193,
#  'conditions': 301,
#  'tends': 118,
#  'read': 1675,
#  'sunlight': 338,
#  'sensor': 432,
#  'reflective': 20,
#  'coating': 56,
#  'entry': 269,
#  'store': 1957,
#  "contact's": 9,
#  'info': 376,
#  'fax': 8,
#  'etc': 1894,
#  'notepad': 35,
#  'vocal': 7,
#  'notes': 302,
#  'clock': 245,
#  "i'll": 1107,
#  'looking': 2532,
#  'drives': 50,
#  'disco': 1,
#  'levels': 157,
#  'whisper': 3,
#  'waaay': 5,
#  'holster': 92,
#  "you've": 279,
#  'switched': 487,
#  'moving': 351,
#  'finished': 72,
#  'dc': 25,
#  'mode': 984,
#  'apologizing': 4,
#  'accidentally': 277,
#  'waying': 1,
#  'individual': 111,
#  'behavior': 61,
#  'settings': 1355,
#  'situations': 153,
#  'truck': 29,
#  'meeting': 50,
#  'movie': 210,
#  'customization': 218,
#  'addendum': 14,
#  'position': 159,
#  'removing': 162,
#  'incoming': 151,
#  'note': 2269,
#  'instead': 1232,
#  'adapters': 53,
#  'laptop': 359,
#  'power': 1941,
#  'inverter': 1,
#  'plugs': 49,
#  "vehicle's": 2,
#  'cigarette': 5,
#  'built': 1327,
#  'surge': 8,
#  'protector': 997,
#  'voila': 26,
#  'vehicular': 1,
#  'utilizing': 20,
#  'plug': 575,
#  'socket': 28,
#  'cord': 225,
#  'move': 671,
#  'labeled': 33,
#  'initial': 262,
#  'promotion': 21,
#  'duh': 25,
#  'offered': 346,
#  "there's": 894,
#  'bit': 2390,
#  'walkie': 8,
#  'talkie': 5,
#  'style': 380,
#  '30': 1056,
#  'secs': 13,
#  'chicago': 25,
#  'gps': 1236,
#  'window': 223,
#  'dozens': 53,
#  'surrounding': 20,
#  'suburbs': 9,
#  'miles': 93,
#  'north': 66,
#  'telenav': 11,
#  'company': 995,
#  'mapping': 37,
#  'kilobyte': 3,
#  'comes': 2311,
#  'twenty': 31,
#  'bucks': 406,
#  'addition': 370,
#  'kicker': 13,
#  'hardly': 271,
#  'signed': 72,
#  "year's": 81,
#  'single': 645,
#  'dime': 24,
#  'spoke': 82,
#  'told': 689,
#  'gaurantee': 1,
#  'satelllites': 1,
#  'bunch': 279,
#  'fargin': 1,
#  'iceholes': 1,
#  'stated': 315,
#  'finder': 22,
#  'equivalent': 79,
#  'pages': 310,
#  'snocountry': 1,
#  'tells': 148,
#  'amount': 650,
#  'snow': 14,
#  'hill': 19,
#  'america': 155,
#  "that's": 1943,
#  'candy': 96,
#  'attention': 230,
#  'low': 2082,
#  'purse': 135,
#  'ringer': 163,
#  'muffle': 6,
#  'reviewed': 92,
#  'endorsements': 1,
#  'met': 131,
#  'specifications': 146,
#  'acquiring': 9,
#  'conclusion': 290,
#  'appears': 376,
#  'plagued': 43,
#  'manufacturing': 71,
#  'standards': 146,
#  'slightly': 737,
#  'components': 70,
#  'higher': 691,
#  'rates': 81,
#  'sanyo': 18,
#  '8200': 4,
#  'alternatives': 66,
#  'mention': 483,
#  'deals': 100,
#  'signing': 37,
#  'agreement': 32,
#  'yippie': 2,
#  'appointment': 39,
#  'current': 657,
#  "let's": 271,
#  'raised': 80,
#  'daytime': 34,
#  '4900': 1,
#  '8300': 6,
#  'cut': 388,
#  'corners': 108,
#  'demands': 33,
#  'location': 397,
#  'mm7500': 1,
#  '9000': 15,
#  'gen': 195,
#  'averages': 5,
#  'recorder': 97,
#  'advertised': 563,
#  'switching': 469,
#  'warrantee': 8,
#  'countless': 55,
#  'swap': 216,
#  'reviewers': 246,
#  'sounding': 77,
#  'garbled': 20,
#  'conversations': 84,
#  'utilize': 63,
#  'return': 1326,
#  'policy': 125,
#  'line': 1235,
#  'mindful': 6,
#  'firmware': 326,
#  'version': 2029,
#  'replacement': 1211,
#  'versions': 358,
#  'shipping': 761,
#  'rev': 12,
#  '25': 417,
#  'update': 2901,
#  '29': 100,
#  'accessories': 555,
#  'manufacturers': 185,
#  'apply': 106,
#  'wishes': 17,
#  'mean': 615,
#  '5th': 57,
#  '4500': 3,
#  'numerous': 147,
#  'occasion': 60,
#  'half': 1085,
#  'duplex': 8,
#  'speakerphones': 1,
#  'hd': 904,
#  'expect': 1046,
#  'board': 251,
#  'tiny': 472,
#  'micro': 1471,
#  'sized': 313,
#  'performance': 1621,
#  'venerable': 5,
#  'scp': 2,
#  '8100': 13,
#  '5300': 4,
#  'released': 477,
#  'july': 124,
#  '2002': 12,
#  'pm': 64,
#  'addressed': 66,
#  'sports': 105,
#  'picture': 1169,
#  "8100's": 1,
#  'streaks': 10,
#  'colors': 836,
#  "8200's": 1,
#  'task': 261,
#  'headsets': 81,
#  'thanks': 1403,
#  'save': 788,
#  'depletes': 13,
#  'holds': 298,
#  'customized': 105,
#  'mini': 771,
#  'scheme': 57,
#  'summary': 177,
#  'delivers': 111,
#  'recording': 269,
#  'check': 933,
#  'toshiba': 7,
#  'ago': 1074,
#  'hungary': 1,
#  'somewhat': 371,
#  'discussion': 20,
#  'visit': 76,
#  'discovered': 214,
#  "motorola's": 71,
#  "v600's": 3,
#  'standby': 291,
#  ...}

# %%
word_cloud_lst = sorted(countDict.items(), key=lambda x: x[1], reverse=True)
word_cloud_lst
# Out:
# [('phone', 32164),
#  ('screen', 9874),
#  ('battery', 9030),
#  ('phones', 7318),
#  ('camera', 7070),
#  ('price', 6968),
#  ('time', 6516),
#  ('2', 5678),
#  ('android', 5468),
#  ('bought', 5420),
#  ('apps', 5369),
#  ('quality', 5314),
#  ('got', 5250),
#  ('life', 5226),
#  ('am', 5070),
#  ('product', 5048),
#  ('buy', 5005),
#  ('5', 4914),
#  ('card', 4761),
#  ("i'm", 4716),
#  ('using', 4662),
#  ('3', 4574),
#  ('4', 4482),
#  ('samsung', 4378),
#  ("i've", 3905),
#  ('1', 3886),
#  ('little', 3837),
#  ('day', 3797),
#  ('features', 3634),
#  ('iphone', 3567),
#  ('sim', 3469),
#  ('lot', 3444),
#  ('size', 3232),
#  ('device', 3223),
#  ('mobile', 3216),
#  ('galaxy', 3015),
#  ('days', 2953),
#  ('call', 2916),
#  ('update', 2901),
#  ('amazon', 2890),
#  ('app', 2840),
#  ('service', 2821),
#  ('calls', 2727),
#  ('getting', 2602),
#  ('people', 2588),
#  ('months', 2583),
#  ('memory', 2563),
#  ('charge', 2534),
#  ('looking', 2532),
#  ('unlocked', 2509),
#  ('6', 2485),
#  ('able', 2463),
#  ('data', 2457),
#  ('ok', 2436),
#  ('sd', 2423),
#  ('smartphone', 2403),
#  ('bit', 2390),
#  ('google', 2387),
#  ('cell', 2353),
#  ('comes', 2311),
#  ('pictures', 2302),
#  ('looks', 2273),
#  ('note', 2269),
#  ('overall', 2253),
#  ('money', 2234),
#  ('light', 2227),
#  ('software', 2222),
#  ('look', 2221),
#  ('touch', 2213),
#  ('text', 2211),
#  ('music', 2192),
#  ('sound', 2191),
#  ('purchase', 2176),
#  ('wifi', 2168),
#  ('times', 2132),
#  ('review', 2126),
#  ('purchased', 2116),
#  ('found', 2115),
#  ('display', 2106),
#  ('takes', 2105),
#  ('excelente', 2100),
#  ('feel', 2086),
#  ('lg', 2086),
#  ('low', 2082),
#  ('makes', 2079),
#  ('feature', 2076),
#  ('user', 2075),
#  ('actually', 2062),
#  ('version', 2029),
#  ('video', 2024),
#  ('set', 1957),
#  ('store', 1957),
#  ('10', 1946),
#  ("that's", 1943),
#  ('power', 1941),
#  ('etc', 1894),
#  ('deal', 1890),
#  ('charger', 1880),
#  ('storage', 1874),
#  ('home', 1863),
#  ('front', 1858),
#  ('100', 1841),
#  ('button', 1833),
#  ('high', 1832),
#  ('os', 1814),
#  ('8', 1811),
#  ('verizon', 1806),
#  ('hours', 1804),
#  ('play', 1797),
#  ('4g', 1791),
#  ('internet', 1789),
#  ('plus', 1752),
#  ('keyboard', 1729),
#  ('month', 1728),
#  ('hand', 1723),
#  ('charging', 1721),
#  ('windows', 1713),
#  ('box', 1696),
#  ('upgrade', 1693),
#  ('speaker', 1682),
#  ('seller', 1682),
#  ('read', 1675),
#  ('tried', 1668),
#  ('plan', 1663),
#  ('experience', 1662),
#  ('7', 1630),
#  ('performance', 1621),
#  ('easily', 1621),
#  ('try', 1608),
#  ("you're", 1603),
#  ('received', 1598),
#  ('minutes', 1576),
#  ('system', 1572),
#  ('network', 1568),
#  ('htc', 1568),
#  ('own', 1549),
#  ('games', 1533),
#  ('probably', 1522),
#  ('lte', 1509),
#  ('bluetooth', 1501),
#  ('processor', 1501),
#  ('speed', 1495),
#  ('reason', 1495),
#  ('feels', 1489),
#  ('pay', 1484),
#  ('nokia', 1478),
#  ('expected', 1478),
#  ('volume', 1474),
#  ('micro', 1471),
#  ('photos', 1466),
#  ('definitely', 1459),
#  ('model', 1447),
#  ('reviews', 1442),
#  ('voice', 1419),
#  ('blu', 1417),
#  ('stars', 1415),
#  ('running', 1415),
#  ('thanks', 1403),
#  ('web', 1395),
#  ('0', 1392),
#  ('design', 1388),
#  ('run', 1374),
#  ('couple', 1372),
#  ('videos', 1372),
#  ('resolution', 1367),
#  ('compared', 1364),
#  ('especially', 1362),
#  ('buying', 1360),
#  ('settings', 1355),
#  ('brand', 1353),
#  ('quickly', 1352),
#  ('hold', 1351),
#  ('buttons', 1350),
#  ('sometimes', 1340),
#  ('quick', 1332),
#  ('3g', 1331),
#  ('talk', 1330),
#  ('built', 1327),
#  ('email', 1326),
#  ('return', 1326),
#  ('pocket', 1319),
#  ('simple', 1306),
#  ('owned', 1298),
#  ('cost', 1295),
#  ('apple', 1292),
#  ('ram', 1285),
#  ('real', 1284),
#  ('download', 1268),
#  ('week', 1267),
#  ('change', 1265),
#  ('market', 1251),
#  ('else', 1248),
#  ('wish', 1239),
#  ('gps', 1236),
#  ('hands', 1235),
#  ('motorola', 1235),
#  ('line', 1235),
#  ('instead', 1232),
#  ('devices', 1228),
#  ('basic', 1223),
#  ('maybe', 1219),
#  ('add', 1217),
#  ('wife', 1215),
#  ('replacement', 1211),
#  ('installed', 1207),
#  ('replace', 1204),
#  ('flash', 1196),
#  ('extra', 1195),
#  ('huge', 1189),
#  ('signal', 1186),
#  ('dual', 1182),
#  ('usb', 1182),
#  ('send', 1180),
#  ('yes', 1178),
#  ('tell', 1172),
#  ('weeks', 1171),
#  ('trying', 1171),
#  ('slot', 1171),
#  ('picture', 1169),
#  ('heavy', 1168),
#  ('dropped', 1166),
#  ('cover', 1162),
#  ('mine', 1154),
#  ('highly', 1144),
#  ('due', 1139),
#  ('contract', 1135),
#  ('left', 1130),
#  ('finally', 1127),
#  ('updates', 1117),
#  ('customer', 1114),
#  ("i'll", 1107),
#  ('carrier', 1102),
#  ('texting', 1098),
#  ('option', 1092),
#  ('start', 1089),
#  ('nexus', 1088),
#  ('help', 1087),
#  ('half', 1085),
#  ('internal', 1084),
#  ("i'd", 1079),
#  ('live', 1079),
#  ('ago', 1074),
#  ('started', 1072),
#  ('runs', 1069),
#  ('access', 1069),
#  ('condition', 1067),
#  ('decided', 1064),
#  ('30', 1056),
#  ('build', 1049),
#  ('plastic', 1047),
#  ('expect', 1046),
#  ('absolutely', 1045),
#  ('blackberry', 1044),
#  ('color', 1040),
#  ('arrived', 1034),
#  ('unless', 1028),
#  ('simply', 1026),
#  ('hardware', 1025),
#  ('bigger', 1024),
#  ('wireless', 1023),
#  ('type', 1018),
#  ('space', 1017),
#  ('paid', 1013),
#  ('item', 1008),
#  ('previous', 1007),
#  ('value', 1002),
#  ('protector', 997),
#  ('black', 996),
#  ('taking', 996),
#  ('company', 995),
#  ('normal', 994),
#  ('specs', 993),
#  ('doing', 986),
#  ('original', 986),
#  ('mode', 984),
#  ('speakers', 982),
#  ('close', 973),
#  ('person', 971),
#  ('job', 961),
#  ('reception', 960),
#  ('options', 956),
#  ('star', 950),
#  ('moto', 947),
#  ('larger', 944),
#  ('completely', 943),
#  ('interface', 942),
#  ('called', 937),
#  ('check', 933),
#  ('bottom', 927),
#  ('sent', 922),
#  ('s4', 918),
#  ('coming', 916),
#  ('glass', 914),
#  ('except', 912),
#  ('main', 912),
#  ('difference', 909),
#  ('returned', 905),
#  ('hd', 904),
#  ('means', 898),
#  ('20', 897),
#  ('hope', 897),
#  ('soon', 895),
#  ('believe', 894),
#  ("there's", 894),
#  ('bloatware', 893),
#  ('usage', 883),
#  ('car', 881),
#  ("you'll", 880),
#  ('seen', 874),
#  ('fit', 871),
#  ('install', 865),
#  ('course', 860),
#  ('goes', 859),
#  ('hear', 859),
#  ('gb', 859),
#  ('switch', 855),
#  ('warranty', 849),
#  ('online', 849),
#  ('included', 846),
#  ('operating', 845),
#  ('users', 841),
#  ('functions', 840),
#  ('mind', 837),
#  ('colors', 836),
#  ('short', 829),
#  ('messages', 826),
#  ('core', 826),
#  ('cards', 822),
#  ('fix', 820),
#  ('computer', 818),
#  ('care', 818),
#  ('otherwise', 814),
#  ('s5', 814),
#  ('stuff', 811),
#  ('gift', 811),
#  ('50', 809),
#  ('wait', 808),
#  ('stock', 807),
#  ('cable', 800),
#  ('s3', 797),
#  ('exactly', 791),
#  ('playing', 790),
#  ('save', 788),
#  ('described', 788),
#  ('similar', 784),
#  ('connection', 779),
#  ('extremely', 779),
#  ('standard', 778),
#  ('reading', 776),
#  ('drop', 775),
#  ('setting', 773),
#  ('mini', 771),
#  ('choice', 770),
#  ('past', 769),
#  ('player', 768),
#  ('replaced', 766),
#  ('shipping', 761),
#  ('including', 760),
#  ('facebook', 759),
#  ('average', 758),
#  ('smartphones', 758),
#  ('guess', 756),
#  ('added', 755),
#  ('edge', 755),
#  ('15', 754),
#  ('youtube', 753),
#  ('world', 752),
#  ('radio', 752),
#  ('connect', 749),
#  ('sprint', 748),
#  ('straight', 747),
#  ('contacts', 747),
#  ('function', 744),
#  ('gsm', 743),
#  ('receive', 743),
#  ('thin', 743),
#  ('lasts', 739),
#  ('facing', 738),
#  ('lots', 737),
#  ('screens', 737),
#  ('slightly', 737),
#  ('headphones', 732),
#  ('tablet', 732),
#  ('spend', 730),
#  ('calling', 729),
#  ('major', 726),
#  ('via', 724),
#  ('son', 724),
#  ('range', 720),
#  ('night', 719),
#  ('white', 716),
#  ('regular', 716),
#  ('fits', 715),
#  ('att', 715),
#  ('products', 710),
#  ('audio', 709),
#  ('allows', 704),
#  ('port', 703),
#  ('watch', 702),
#  ('microsd', 702),
#  ("phone's", 697),
#  ('looked', 697),
#  ('flip', 695),
#  ('updated', 695),
#  ('cameras', 693),
#  ('water', 692),
#  ('matter', 691),
#  ('higher', 691),
#  ('usually', 691),
#  ('unlock', 691),
#  ('ones', 690),
#  ('told', 689),
#  ('browsing', 689),
#  ('factory', 686),
#  ('sony', 685),
#  ('account', 685),
#  ('okay', 681),
#  ('anyway', 680),
#  ('please', 679),
#  ('applications', 678),
#  ('charged', 678),
#  ('message', 677),
#  ('inch', 677),
#  ('true', 672),
#  ('removable', 672),
#  ('daughter', 672),
#  ('move', 671),
#  ('lock', 669),
#  ('lumia', 666),
#  ('browser', 665),
#  ('tracfone', 664),
#  ('12', 662),
#  ('friends', 660),
#  ('tech', 659),
#  ('current', 657),
#  ('fi', 657),
#  ('9', 656),
#  ('amount', 650),
#  ('constantly', 650),
#  ('media', 650),
#  ('name', 647),
#  ('international', 646),
#  ('single', 645),
#  ('noticed', 645),
#  ('32gb', 645),
#  ('considering', 643),
#  ('notice', 641),
#  ('opinion', 639),
#  ('business', 639),
#  ('based', 638),
#  ('family', 638),
#  ('brightness', 636),
#  ('plenty', 632),
#  ('budget', 630),
#  ('press', 623),
#  ('stopped', 620),
#  ('ability', 618),
#  ('carry', 618),
#  ('sold', 618),
#  ('piece', 616),
#  ('droid', 616),
#  ('mean', 615),
#  ('keys', 613),
#  ('currently', 612),
#  ('maps', 612),
#  ('class', 612),
#  ('remove', 611),
#  ('list', 610),
#  ('texts', 608),
#  ('allow', 607),
#  ('pre', 607),
#  ('locked', 606),
#  ('photo', 605),
#  ('fixed', 605),
#  ('auto', 602),
#  ('lower', 597),
#  ('kept', 596),
#  ('wi', 595),
#  ('weight', 593),
#  ('lollipop', 591),
#  ('stay', 590),
#  ('hour', 590),
#  ('talking', 590),
#  ('menu', 588),
#  ('reset', 588),
#  ('basically', 587),
#  ('beat', 587),
#  ('waiting', 586),
#  ('oh', 585),
#  ('control', 585),
#  ('level', 584),
#  ('near', 584),
#  ('understand', 584),
#  ('downloaded', 583),
#  ('contact', 583),
#  ('connected', 581),
#  ('key', 577),
#  ('quad', 576),
#  ('plug', 575),
#  ('none', 571),
#  ('refurbished', 571),
#  ('friend', 569),
#  ('hit', 567),
#  ('technology', 566),
#  ('date', 564),
#  ('unit', 563),
#  ('advertised', 563),
#  ('offer', 561),
#  ('outside', 559),
#  ('functionality', 559),
#  ('watching', 557),
#  ('accessories', 555),
#  ('transfer', 553),
#  ('future', 553),
#  ('manual', 553),
#  ('200', 553),
#  ('surprised', 552),
#  ('fan', 551),
#  ('sounds', 550),
#  ('charges', 550),
#  ('despite', 548),
#  ('daily', 548),
#  ('nearly', 548),
#  ('multiple', 546),
#  ('rear', 546),
#  ('load', 545),
#  ('totally', 545),
#  ('pics', 544),
#  ('figure', 544),
#  ('missing', 544),
#  ('consider', 543),
#  ('game', 542),
#  ('backup', 541),
#  ('search', 540),
#  ('16gb', 540),
#  ('ui', 537),
#  ('choose', 536),
#  ('test', 536),
#  ('navigation', 536),
#  ('files', 535),
#  ('third', 535),
#  ('minor', 534),
#  ('compare', 534),
#  ('mail', 534),
#  ('cellphone', 534),
#  ('ios', 534),
#  ('saying', 533),
#  ('below', 532),
#  ('prepaid', 530),
#  ('twice', 529),
#  ('example', 528),
#  ('focus', 525),
#  ('16', 525),
#  ('recently', 523),
#  ('im', 521),
#  ('movies', 521),
#  ('biggest', 520),
#  ('cant', 520),
#  ('personal', 517),
#  ('holding', 516),
#  ('blue', 515),
#  ('offers', 515),
#  ('com', 515),
#  ('immediately', 514),
#  ('unlike', 510),
#  ('stop', 506),
#  ('fingerprint', 505),
#  ('personally', 504),
#  ('flagship', 504),
#  ('link', 502),
#  ('handle', 500),
#  ('setup', 498),
#  ('emails', 498),
#  ('remember', 497),
#  ('activated', 494),
#  ('finger', 494),
#  ('view', 493),
#  ('expectations', 493),
#  ('information', 493),
#  ('carriers', 492),
#  ('loaded', 492),
#  ('anymore', 492),
#  ('notification', 491),
#  ('thinking', 490),
#  ('leave', 489),
#  ('pick', 489),
#  ('external', 487),
#  ('switched', 487),
#  ('website', 485),
#  ('default', 484),
#  ('giving', 484),
#  ('mention', 483),
#  ('microsoft', 483),
#  ('images', 481),
#  ('models', 481),
#  ('iphones', 481),
#  ('idea', 480),
#  ('automatically', 480),
#  ('released', 477),
#  ('five', 477),
#  ('sense', 477),
#  ('activate', 477),
#  ('inside', 474),
#  ('producto', 473),
#  ('tiny', 472),
#  ('local', 471),
#  ('physical', 471),
#  ('process', 470),
#  ('travel', 470),
#  ('messaging', 469),
#  ('switching', 469),
#  ('heard', 468),
#  ('yourself', 468),
#  ('gone', 466),
#  ('rating', 466),
#  ('supposed', 465),
#  ('research', 464),
#  ('bar', 463),
#  ('venezuela', 462),
#  ('truly', 461),
#  ('speeds', 461),
#  ('coverage', 460),
#  ('root', 459),
#  ('changed', 458),
#  ('batteries', 455),
#  ('delivery', 455),
#  ('background', 452),
#  ('directly', 452),
#  ('honestly', 452),
#  ('rate', 450),
#  ('answer', 449),
#  ('40', 448),
#  ('ear', 448),
#  ('comparison', 448),
#  ('64gb', 447),
#  ('typing', 446),
#  ('image', 445),
#  ('designed', 444),
#  ('99', 443),
#  ('package', 441),
#  ('tv', 441),
#  ('page', 440),
#  ('barely', 440),
#  ('touchscreen', 439),
#  ('helps', 438),
#  ('write', 437),
#  ('paying', 436),
#  ('husband', 436),
#  ('metal', 435),
#  ('amoled', 433),
#  ('cellular', 432),
#  ('whatever', 432),
#  ('sensor', 432),
#  ('additional', 431),
#  ('party', 428),
#  ('sync', 427),
#  ('slim', 427),
#  ('kids', 427),
#  ('office', 426),
#  ('00', 426),
#  ('response', 426),
#  ('mom', 426),
#  ('calendar', 425),
#  ('spent', 425),
#  ('purchasing', 425),
#  ('s6', 425),
#  ('dollars', 423),
#  ('mp', 418),
#  ('learning', 418),
#  ('mp3', 417),
#  ('25', 417),
#  ('listen', 417),
#  ('pc', 416),
#  ('headset', 416),
#  ('tap', 416),
#  ('step', 415),
#  ('learn', 414),
#  ('form', 414),
#  ('32', 413),
#  ('sending', 412),
#  ('complete', 410),
#  ('double', 408),
#  ('minute', 407),
#  ('drive', 407),
#  ('bucks', 406),
#  ('stand', 405),
#  ('tmobile', 402),
#  ('bueno', 402),
#  ('launcher', 401),
#  ('onto', 400),
#  ('premium', 400),
#  ('tested', 399),
#  ('provider', 398),
#  ('cpu', 398),
#  ('location', 397),
#  ('functional', 397),
#  ('virgin', 397),
#  ('13', 396),
#  ('description', 395),
#  ('fingers', 394),
#  ('rest', 394),
#  ('con', 394),
#  ('fm', 393),
#  ('8gb', 393),
#  ('qwerty', 392),
#  ('sell', 392),
#  ('lasted', 391),
#  ('muy', 391),
#  ('moderate', 390),
#  ('icons', 390),
#  ('pro', 390),
#  ('total', 388),
#  ('cut', 388),
#  ('happen', 388),
#  ('country', 387),
#  ('word', 387),
#  ('site', 386),
#  ('program', 386),
#  ('factor', 386),
#  ('terms', 385),
#  ('mentioned', 384),
#  ('gotten', 383),
#  ('11', 382),
#  ('selling', 382),
#  ('ie', 382),
#  ('happened', 381),
#  ('capabilities', 381),
#  ('24', 380),
#  ('style', 380),
#  ('networks', 379),
#  ('60', 379),
#  ('drops', 378),
#  ('capacity', 378),
#  ('services', 378),
#  ('ring', 377),
#  ('push', 376),
#  ('info', 376),
#  ('appears', 376),
#  ('include', 376),
#  ('jack', 376),
#  ('expandable', 376),
#  ('application', 375),
#  ('viewing', 375),
#  ('adapter', 375),
#  ('seriously', 374),
#  ('house', 373),
#  ('1080p', 373),
#  ('pop', 372),
#  ('somewhat', 371),
#  ('addition', 370),
#  ('2015', 369),
#  ('priced', 367),
#  ('stereo', 366),
#  ('cause', 366),
#  ('entire', 364),
#  ('edit', 363),
#  ('keeping', 363),
#  ('shots', 362),
#  ('social', 362),
#  ('actual', 361),
#  ('chance', 361),
#  ('studio', 361),
#  ('removed', 361),
#  ('bring', 360),
#  ('active', 360),
#  ('usa', 360),
#  ('g3', 360),
#  ('2nd', 359),
#  ('laptop', 359),
#  ('requires', 359),
#  ('putting', 358),
#  ('middle', 358),
#  ('versions', 358),
#  ('returning', 358),
#  ('listening', 358),
#  ('repair', 357),
#  ('2gb', 356),
#  ('gorilla', 356),
#  ('body', 355),
#  ('book', 354),
#  ('experienced', 353),
#  ('obviously', 352),
#  ('release', 351),
#  ('moving', 351),
#  ('pixel', 350),
#  ('period', 350),
#  ('4s', 350),
#  ('slide', 349),
#  ('hook', 348),
#  ('300', 348),
#  ('wall', 348),
#  ('figured', 347),
#  ('band', 346),
#  ('offered', 346),
#  ('code', 346),
#  ('reasons', 345),
#  ('gaming', 345),
#  ('security', 343),
#  ('surprisingly', 342),
#  ('everyday', 342),
#  ('reboot', 341),
#  ('common', 341),
#  ('shut', 341),
#  ('notifications', 341),
#  ('kitkat', 341),
#  ('vs', 340),
#  ('re', 340),
#  ('provided', 340),
#  ('speakerphone', 339),
#  ('sunlight', 338),
#  ('downloading', 338),
#  ('shipped', 338),
#  ('sale', 337),
#  ('netflix', 337),
#  ('streaming', 336),
#  ('snapdragon', 336),
#  ('click', 335),
#  ('forget', 335),
#  ('spare', 335),
#  ('par', 335),
#  ('series', 335),
#  ('forward', 334),
#  ('plans', 333),
#  ('pen', 333),
#  ('particular', 333),
#  ('monthly', 332),
#  ("they're", 332),
#  ('realize', 329),
#  ('happens', 329),
#  ('headphone', 329),
#  ('news', 329),
#  ('provide', 329),
#  ('require', 328),
#  ('pixels', 327),
#  ('dial', 326),
#  ('firmware', 326),
#  ('besides', 326),
#  ('5s', 325),
#  ('moved', 324),
#  ('apparently', 324),
#  ('aware', 324),
#  ('guy', 324),
#  ('hopefully', 323),
#  ('mid', 323),
#  ('restart', 323),
#  ('file', 322),
#  ('delete', 322),
#  ('stylus', 321),
#  ('includes', 321),
#  ('previously', 320),
#  ('various', 320),
#  ('saving', 319),
#  ('3rd', 318),
#  ('direct', 318),
#  ('red', 317),
#  ('performs', 316),
#  ('suggest', 315),
#  ('stated', 315),
#  ('address', 315),
#  ('expecting', 315),
#  ('reader', 315),
#  ('razr', 315),
#  ('depending', 315),
#  ('curve', 314),
#  ('sized', 313),
#  ('lol', 313),
#  ('serious', 313),
#  ('installing', 312),
#  ('recent', 312),
#  ('feeling', 312),
#  ('specific', 311),
#  ('2014', 311),
#  ('multi', 310),
#  ('alot', 310),
#  ('pages', 310),
#  ('g2', 309),
#  ('special', 308),
#  ('careful', 308),
#  ('rom', 308),
#  ('delivered', 308),
#  ('exelente', 308),
#  ('instructions', 307),
#  ('spot', 307),
#  ('starting', 306),
#  ('companies', 306),
#  ('custom', 306),
#  ('linked', 306),
#  ('plugged', 306),
#  ('doesnt', 306),
#  ('90', 306),
#  ('packaging', 306),
#  ('ref', 306),
#  ('ton', 305),
#  ('stick', 305),
#  ('operate', 305),
#  ('asus', 305),
#  ('zoom', 304),
#  ('programs', 304),
#  ('eventually', 304),
#  ('upgrading', 304),
#  ('frequently', 303),
#  ('costs', 303),
#  ('required', 303),
#  ('g4', 303),
#  ('2016', 303),
#  ('600', 302),
#  ('notes', 302),
#  ('skype', 302),
#  ('conditions', 301),
#  ('xperia', 301),
#  ('driving', 300),
#  ('tasks', 300),
#  ('14', 300),
#  ('icon', 299),
#  ('adding', 299),
#  ('exchange', 298),
#  ('navigate', 298),
#  ('holds', 298),
#  ('items', 298),
#  ('connectivity', 297),
#  ('receiving', 297),
#  ('english', 296),
#  ('utf8', 296),
#  ('words', 295),
#  ('thats', 295),
#  ('listed', 294),
#  ('id', 292),
#  ('rid', 292),
#  ('boot', 292),
#  ('post', 292),
#  ('wide', 292),
#  ('played', 292),
#  ('provides', 292),
#  ('4gb', 292),
#  ('standby', 291),
#  ('tons', 291),
#  ('pull', 291),
#  ('scanner', 291),
#  ('conclusion', 290),
#  ('forever', 290),
#  ('dp', 290),
#  ('sort', 289),
#  ('writing', 289),
#  ('acceptable', 289),
#  ('details', 289),
#  ('lens', 289),
#  ('menus', 288),
#  ('questions', 288),
#  ('select', 288),
#  ('moment', 287),
#  ('beyond', 287),
#  ('picked', 287),
#  ('chose', 286),
#  ('adjust', 286),
#  ('slippery', 286),
#  ('bill', 285),
#  ('customize', 285),
#  ('hoping', 285),
#  ('continue', 284),
#  ('input', 284),
#  ('keypad', 283),
#  ('gmail', 283),
#  ('weather', 282),
#  ('earlier', 282),
#  ('decision', 282),
#  ('zero', 282),
#  ('2g', 282),
#  ('palm', 281),
#  ('noticeable', 281),
#  ('ran', 281),
#  ('lighting', 281),
#  ('nbsp', 281),
#  ('inches', 281),
#  ('bars', 280),
#  ('changes', 280),
#  ('nfc', 280),
#  ('shot', 279),
#  ('comparing', 279),
#  ('surfing', 279),
#  ("you've", 279),
#  ('bunch', 279),
#  ('customers', 279),
#  ('ultra', 279),
#  ('beats', 279),
#  ('bells', 278),
#  ('waterproof', 278),
#  ('accidentally', 277),
#  ('prime', 277),
#  ('share', 277),
#  ('avoid', 276),
#  ('400', 276),
#  ('resistant', 276),
#  ('dropping', 275),
#  ('2013', 275),
#  ("what's", 274),
#  ('1gb', 274),
#  ('contacted', 274),
#  ('bien', 274),
#  ('ipod', 273),
#  ('processing', 273),
#  ...]

# %%
#positive corpus
positive_corpus = phone_data_top_10[phone_data_top_10.review_sentiment == 'POSITIVE']
positive_corpus = positive_corpus[["cleaned_reviewText", "brand"]]
cleaned_review = positive_corpus["cleaned_reviewText"]
#removing stop words from all reviews
no_positivewords_review = []

for review in cleaned_review:
    word_tokens = review.split() 
#     filtered_sentence = [w for w in word_tokens if not w in pos_words] 
    filtered_sentence = [w for w in word_tokens if  w in ['screen', 'battery', 'camera', 'price', 'quality', 'life', 'charger', 'charge', 'display', 'power', 'storage', 'button']] 
    no_positivewords_review.append(' '.join(filtered_sentence))

positive_corpus["cleaned_reviewText"] = no_positivewords_review
positive_corpus.to_excel("/content/drive/My Drive/sentiment_analysis/positive_corpus.xlsx", index = False)

# %%
#negative corpus
negative_corpus = phone_data_top_10[phone_data_top_10.review_sentiment == 'NEGATIVE']
negative_corpus = negative_corpus[["cleaned_reviewText", "brand"]]
cleaned_review = negative_corpus["cleaned_reviewText"]

#removing stop words from all reviews
no_negativewords_review = []

for review in cleaned_review:
  if type(review) == str:
    word_tokens = review.split() 
    filtered_sentence = [w for w in word_tokens if w in ['screen', 'battery', 'camera', 'price', 'quality', 'life', 'charger', 'charge', 'display', 'power', 'storage', 'button']] 
    no_negativewords_review.append(' '.join(filtered_sentence))
  else:
    continue
 
negative_corpus["cleaned_reviewText"] = no_negativewords_review
negative_corpus.to_excel("/content/drive/My Drive/sentiment_analysis/negative_corpus.xlsx", index = False)

# %%
# import math
# def computeIDFDict():
#     """ Returns a dictionary whose keys are all the unique words in the
#     dataset and whose values are their corresponding idf.
#     """
#     idfDict = {}
#     for word in countDict:
#         idfDict[word] = math.log(len(cleaned_review) / countDict[word])
#     return idfDict
  
# # Stores the idf dictionary
# idfDict = computeIDFDict()
